# %% [markdown]
# # Cherry Blossoms!
#
# If we travel back in time a few months, [cherry blossoms](https://en.wikipedia.org/wiki/Cherry_blossom) were in full bloom! We don't live in Japan or DC, but we do have our fair share of the trees - buuut you sadly missed [Brooklyn Botanic Garden's annual festival](https://www.bbg.org/visit/event/sakura_matsuri_2019).
#
# We'll have to make up for it with data-driven cherry blossoms instead. Once upon a time [Data is Plural](https://tinyletter.com/data-is-plural) linked to [a dataset](http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/) about when the cherry trees blossom each year. It's a little out of date, but it's quirky in a real nice way so we're sticking with it.
#
# ## 0. Do all of your importing/setup stuff

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## 1. Read in the file using pandas, and look at the first five rows

# %%
df = pd.read_excel("KyotoFullFlower7.xls")
df.head(5)
# Out:
#   Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 0  This phenological data was acquired by followi...
# 1                                                NaN
# 2                                     Column A; A.D.
# 3       Column B; Full-flowering date (day of year).
# 4  Column C; Full-flowering date (calender date, ...
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN

# %% [markdown]
# ## 2. Read in the file using pandas CORRECTLY, and look at the first five rows
#
# Hrm, how do your column names look? Read the file in again but this time add a parameter to make sure your columns look right.
#
# **TIP: The first year should be 801 AD, and it should not have any dates or anything.**

# %%
df=df[25:]
df
# Out:
#      Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 25                                                  801
# 26                                                  802
# 27                                                  803
# 28                                                  804
# 29                                                  805
# 30                                                  806
# 31                                                  807
# 32                                                  808
# 33                                                  809
# 34                                                  810
# 35                                                  811
# 36                                                  812
# 37                                                  813
# 38                                                  814
# 39                                                  815
# 40                                                  816
# 41                                                  817
# 42                                                  818
# 43                                                  819
# 44                                                  820
# 45                                                  821
# 46                                                  822
# 47                                                  823
# 48                                                  824
# 49                                                  825
# 50                                                  826
# 51                                                  827
# 52                                                  828
# 53                                                  829
# 54                                                  830
# ...                                                 ...
# 1210                                               1986
# 1211                                               1987
# 1212                                               1988
# 1213                                               1989
# 1214                                               1990
# 1215                                               1991
# 1216                                               1992
# 1217                                               1993
# 1218                                               1994
# 1219                                               1995
# 1220                                               1996
# 1221                                               1997
# 1222                                               1998
# 1223                                               1999
# 1224                                               2000
# 1225                                               2001
# 1226                                               2002
# 1227                                               2003
# 1228                                               2004
# 1229                                               2005
# 1230                                               2006
# 1231                                               2007
# 1232                                               2008
# 1233                                               2009
# 1234                                               2010
# 1235                                               2011
# 1236                                               2012
# 1237                                               2013
# 1238                                               2014
# 1239                                               2015
#
#      Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4              Unnamed: 5
# 25          NaN        NaN        NaN        NaN                       -
# 26          NaN        NaN        NaN        NaN                       -
# 27          NaN        NaN        NaN        NaN                       -
# 28          NaN        NaN        NaN        NaN                       -
# 29          NaN        NaN        NaN        NaN                       -
# 30          NaN        NaN        NaN        NaN                       -
# 31          NaN        NaN        NaN        NaN                       -
# 32          NaN        NaN        NaN        NaN                       -
# 33          NaN        NaN        NaN        NaN                       -
# 34          NaN        NaN        NaN        NaN                       -
# 35          NaN        NaN        NaN        NaN                       -
# 36           92        401          1          2              NIHON-KOKI
# 37          NaN        NaN        NaN        NaN                       -
# 38          NaN        NaN        NaN        NaN                       -
# 39          105        415          1          2              NIHON-KOKI
# 40          NaN        NaN        NaN        NaN                       -
# 41          NaN        NaN        NaN        NaN                       -
# 42          NaN        NaN        NaN        NaN                       -
# 43          NaN        NaN        NaN        NaN                       -
# 44          NaN        NaN        NaN        NaN                       -
# 45          NaN        NaN        NaN        NaN                       -
# 46          NaN        NaN        NaN        NaN                       -
# 47          NaN        NaN        NaN        NaN                       -
# 48          NaN        NaN        NaN        NaN                       -
# 49          NaN        NaN        NaN        NaN                       -
# 50          NaN        NaN        NaN        NaN                       -
# 51          NaN        NaN        NaN        NaN                       -
# 52          NaN        NaN        NaN        NaN                       -
# 53          NaN        NaN        NaN        NaN                       -
# 54          NaN        NaN        NaN        NaN                       -
# ...         ...        ...        ...        ...                     ...
# 1210        102        412          3          0  NEWS-PAPER(ARASHIYAMA)
# 1211         95        405          3          0  NEWS-PAPER(ARASHIYAMA)
# 1212        106        415          3          0  NEWS-PAPER(ARASHIYAMA)
# 1213         93        403          3          0  NEWS-PAPER(ARASHIYAMA)
# 1214         88        329          3          0  NEWS-PAPER(ARASHIYAMA)
# 1215         97        407          4          0  NEWS-PAPER(ARASHIYAMA)
# 1216         94        403          4          0  NEWS-PAPER(ARASHIYAMA)
# 1217         97        407          4          0  NEWS-PAPER(ARASHIYAMA)
# 1218         99        409          4          0  NEWS-PAPER(ARASHIYAMA)
# 1219         99        409          4          0  NEWS-PAPER(ARASHIYAMA)
# 1220        103        412          4          0  NEWS-PAPER(ARASHIYAMA)
# 1221         97        407          4          0  NEWS-PAPER(ARASHIYAMA)
# 1222         91        401          4          0  NEWS-PAPER(ARASHIYAMA)
# 1223         94        404          4          0  NEWS-PAPER(ARASHIYAMA)
# 1224        100        409          4          0  NEWS-PAPER(ARASHIYAMA)
# 1225         96        406          4          0  NEWS-PAPER(ARASHIYAMA)
# 1226         91        401          4          0  NEWS-PAPER(ARASHIYAMA)
# 1227         98        408          4          0  NEWS-PAPER(ARASHIYAMA)
# 1228         92        401          4          0  NEWS-PAPER(ARASHIYAMA)
# 1229         99        409          4          0  NEWS-PAPER(ARASHIYAMA)
# 1230         98        408          5          0  NEWS-PAPER(ARASHIYAMA)
# 1231         97        407          5          0  NEWS-PAPER(ARASHIYAMA)
# 1232         95        404          6          0  NEWS-PAPER(ARASHIYAMA)
# 1233         95        405          6          0  NEWS-PAPER(ARASHIYAMA)
# 1234         95        405          7          0  NEWS-PAPER(ARASHIYAMA)
# 1235         99        409          8          0  NEWS-PAPER(ARASHIYAMA)
# 1236        101        410          8          0  NEWS-PAPER(ARASHIYAMA)
# 1237         93        403          8          0  NEWS-PAPER(ARASHIYAMA)
# 1238         94        404          8          0  NEWS-PAPER(ARASHIYAMA)
# 1239         93        403          8          0  NEWS-PAPER(ARASHIYAMA)
#
# [1215 rows x 6 columns]

# %%
df.dtypes
# Out:
# Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)    object
# Unnamed: 1                                                                                                      object
# Unnamed: 2                                                                                                      object
# Unnamed: 3                                                                                                      object
# Unnamed: 4                                                                                                      object
# Unnamed: 5                                                                                                      object
# dtype: object

# %%
df.head(5)
# Out:
#    Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 25                                                801
# 26                                                802
# 27                                                803
# 28                                                804
# 29                                                805
#
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 25        NaN        NaN        NaN        NaN          -
# 26        NaN        NaN        NaN        NaN          -
# 27        NaN        NaN        NaN        NaN          -
# 28        NaN        NaN        NaN        NaN          -
# 29        NaN        NaN        NaN        NaN          -

# %% [markdown]
# ## 3. Look at the final five rows of the data

# %%
df.tail(5)
# Out:
#      Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 1235                                               2011
# 1236                                               2012
# 1237                                               2013
# 1238                                               2014
# 1239                                               2015
#
#      Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4              Unnamed: 5
# 1235         99        409          8          0  NEWS-PAPER(ARASHIYAMA)
# 1236        101        410          8          0  NEWS-PAPER(ARASHIYAMA)
# 1237         93        403          8          0  NEWS-PAPER(ARASHIYAMA)
# 1238         94        404          8          0  NEWS-PAPER(ARASHIYAMA)
# 1239         93        403          8          0  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# ## 4. Add some more NaN values

# %% [markdown]
# It looks like you should probably have some NaN/missing values earlier on in the dataset under "Reference name." Read in the file *one more time*, this time making sure all of those missing reference names actually show up as `NaN` instead of `-`.

# %%
df.replace("-", np.nan, inplace=True)

# %%
df
# Out:
#       Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 25                                                  801
# 26                                                  802
# 27                                                  803
# 28                                                  804
# 29                                                  805
# 30                                                  806
# 31                                                  807
# 32                                                  808
# 33                                                  809
# 34                                                  810
# 35                                                  811
# 36                                                  812
# 37                                                  813
# 38                                                  814
# 39                                                  815
# 40                                                  816
# 41                                                  817
# 42                                                  818
# 43                                                  819
# 44                                                  820
# 45                                                  821
# 46                                                  822
# 47                                                  823
# 48                                                  824
# 49                                                  825
# 50                                                  826
# 51                                                  827
# 52                                                  828
# 53                                                  829
# 54                                                  830
# ...                                                 ...
# 1210                                               1986
# 1211                                               1987
# 1212                                               1988
# 1213                                               1989
# 1214                                               1990
# 1215                                               1991
# 1216                                               1992
# 1217                                               1993
# 1218                                               1994
# 1219                                               1995
# 1220                                               1996
# 1221                                               1997
# 1222                                               1998
# 1223                                               1999
# 1224                                               2000
# 1225                                               2001
# 1226                                               2002
# 1227                                               2003
# 1228                                               2004
# 1229                                               2005
# 1230                                               2006
# 1231                                               2007
# 1232                                               2008
# 1233                                               2009
# 1234                                               2010
# 1235                                               2011
# 1236                                               2012
# 1237                                               2013
# 1238                                               2014
# 1239                                               2015
#
#       Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4              Unnamed: 5
# 25           NaN         NaN         NaN         NaN                     NaN
# 26           NaN         NaN         NaN         NaN                     NaN
# 27           NaN         NaN         NaN         NaN                     NaN
# 28           NaN         NaN         NaN         NaN                     NaN
# 29           NaN         NaN         NaN         NaN                     NaN
# 30           NaN         NaN         NaN         NaN                     NaN
# 31           NaN         NaN         NaN         NaN                     NaN
# 32           NaN         NaN         NaN         NaN                     NaN
# 33           NaN         NaN         NaN         NaN                     NaN
# 34           NaN         NaN         NaN         NaN                     NaN
# 35           NaN         NaN         NaN         NaN                     NaN
# 36          92.0       401.0         1.0         2.0              NIHON-KOKI
# 37           NaN         NaN         NaN         NaN                     NaN
# 38           NaN         NaN         NaN         NaN                     NaN
# 39         105.0       415.0         1.0         2.0              NIHON-KOKI
# 40           NaN         NaN         NaN         NaN                     NaN
# 41           NaN         NaN         NaN         NaN                     NaN
# 42           NaN         NaN         NaN         NaN                     NaN
# 43           NaN         NaN         NaN         NaN                     NaN
# 44           NaN         NaN         NaN         NaN                     NaN
# 45           NaN         NaN         NaN         NaN                     NaN
# 46           NaN         NaN         NaN         NaN                     NaN
# 47           NaN         NaN         NaN         NaN                     NaN
# 48           NaN         NaN         NaN         NaN                     NaN
# 49           NaN         NaN         NaN         NaN                     NaN
# 50           NaN         NaN         NaN         NaN                     NaN
# 51           NaN         NaN         NaN         NaN                     NaN
# 52           NaN         NaN         NaN         NaN                     NaN
# 53           NaN         NaN         NaN         NaN                     NaN
# 54           NaN         NaN         NaN         NaN                     NaN
# ...          ...         ...         ...         ...                     ...
# 1210       102.0       412.0         3.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1211        95.0       405.0         3.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1212       106.0       415.0         3.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1213        93.0       403.0         3.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1214        88.0       329.0         3.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1215        97.0       407.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1216        94.0       403.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1217        97.0       407.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1218        99.0       409.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1219        99.0       409.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1220       103.0       412.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1221        97.0       407.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1222        91.0       401.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1223        94.0       404.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1224       100.0       409.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1225        96.0       406.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1226        91.0       401.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1227        98.0       408.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1228        92.0       401.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1229        99.0       409.0         4.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1230        98.0       408.0         5.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1231        97.0       407.0         5.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1232        95.0       404.0         6.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1233        95.0       405.0         6.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1234        95.0       405.0         7.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1235        99.0       409.0         8.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1236       101.0       410.0         8.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1237        93.0       403.0         8.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1238        94.0       404.0         8.0         0.0  NEWS-PAPER(ARASHIYAMA)
# 1239        93.0       403.0         8.0         0.0  NEWS-PAPER(ARASHIYAMA)
#
# [1215 rows x 6 columns]

# %%
df.rename(columns={'Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)': 'AD', 'Unnamed:_1': 'Full-flowering date'}, inplace=True)

# %%
df.rename(columns={'Unnamed: 1': 'DOY', 'Unnamed: 2': 'Full_flowering_date', 'Unnamed: 3': 'Source_code'}, inplace=True)

# %%
df.rename(columns={'Unnamed: 4': 'Data_type_code', 'Unnamed: 5': 'Reference_Name'}, inplace=True)

# %%
df
# Out:
#         AD    DOY  Full_flowering_date  Source_code  Data_type_code  \
# 25     801    NaN                  NaN          NaN             NaN
# 26     802    NaN                  NaN          NaN             NaN
# 27     803    NaN                  NaN          NaN             NaN
# 28     804    NaN                  NaN          NaN             NaN
# 29     805    NaN                  NaN          NaN             NaN
# 30     806    NaN                  NaN          NaN             NaN
# 31     807    NaN                  NaN          NaN             NaN
# 32     808    NaN                  NaN          NaN             NaN
# 33     809    NaN                  NaN          NaN             NaN
# 34     810    NaN                  NaN          NaN             NaN
# 35     811    NaN                  NaN          NaN             NaN
# 36     812   92.0                401.0          1.0             2.0
# 37     813    NaN                  NaN          NaN             NaN
# 38     814    NaN                  NaN          NaN             NaN
# 39     815  105.0                415.0          1.0             2.0
# 40     816    NaN                  NaN          NaN             NaN
# 41     817    NaN                  NaN          NaN             NaN
# 42     818    NaN                  NaN          NaN             NaN
# 43     819    NaN                  NaN          NaN             NaN
# 44     820    NaN                  NaN          NaN             NaN
# 45     821    NaN                  NaN          NaN             NaN
# 46     822    NaN                  NaN          NaN             NaN
# 47     823    NaN                  NaN          NaN             NaN
# 48     824    NaN                  NaN          NaN             NaN
# 49     825    NaN                  NaN          NaN             NaN
# 50     826    NaN                  NaN          NaN             NaN
# 51     827    NaN                  NaN          NaN             NaN
# 52     828    NaN                  NaN          NaN             NaN
# 53     829    NaN                  NaN          NaN             NaN
# 54     830    NaN                  NaN          NaN             NaN
# ...    ...    ...                  ...          ...             ...
# 1210  1986  102.0                412.0          3.0             0.0
# 1211  1987   95.0                405.0          3.0             0.0
# 1212  1988  106.0                415.0          3.0             0.0
# 1213  1989   93.0                403.0          3.0             0.0
# 1214  1990   88.0                329.0          3.0             0.0
# 1215  1991   97.0                407.0          4.0             0.0
# 1216  1992   94.0                403.0          4.0             0.0
# 1217  1993   97.0                407.0          4.0             0.0
# 1218  1994   99.0                409.0          4.0             0.0
# 1219  1995   99.0                409.0          4.0             0.0
# 1220  1996  103.0                412.0          4.0             0.0
# 1221  1997   97.0                407.0          4.0             0.0
# 1222  1998   91.0                401.0          4.0             0.0
# 1223  1999   94.0                404.0          4.0             0.0
# 1224  2000  100.0                409.0          4.0             0.0
# 1225  2001   96.0                406.0          4.0             0.0
# 1226  2002   91.0                401.0          4.0             0.0
# 1227  2003   98.0                408.0          4.0             0.0
# 1228  2004   92.0                401.0          4.0             0.0
# 1229  2005   99.0                409.0          4.0             0.0
# 1230  2006   98.0                408.0          5.0             0.0
# 1231  2007   97.0                407.0          5.0             0.0
# 1232  2008   95.0                404.0          6.0             0.0
# 1233  2009   95.0                405.0          6.0             0.0
# 1234  2010   95.0                405.0          7.0             0.0
# 1235  2011   99.0                409.0          8.0             0.0
# 1236  2012  101.0                410.0          8.0             0.0
# 1237  2013   93.0                403.0          8.0             0.0
# 1238  2014   94.0                404.0          8.0             0.0
# 1239  2015   93.0                403.0          8.0             0.0
#
#               Reference_Name
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# 30                       NaN
# 31                       NaN
# 32                       NaN
# 33                       NaN
# 34                       NaN
# 35                       NaN
# 36                NIHON-KOKI
# 37                       NaN
# 38                       NaN
# 39                NIHON-KOKI
# 40                       NaN
# 41                       NaN
# 42                       NaN
# 43                       NaN
# 44                       NaN
# 45                       NaN
# 46                       NaN
# 47                       NaN
# 48                       NaN
# 49                       NaN
# 50                       NaN
# 51                       NaN
# 52                       NaN
# 53                       NaN
# 54                       NaN
# ...                      ...
# 1210  NEWS-PAPER(ARASHIYAMA)
# 1211  NEWS-PAPER(ARASHIYAMA)
# 1212  NEWS-PAPER(ARASHIYAMA)
# 1213  NEWS-PAPER(ARASHIYAMA)
# 1214  NEWS-PAPER(ARASHIYAMA)
# 1215  NEWS-PAPER(ARASHIYAMA)
# 1216  NEWS-PAPER(ARASHIYAMA)
# 1217  NEWS-PAPER(ARASHIYAMA)
# 1218  NEWS-PAPER(ARASHIYAMA)
# 1219  NEWS-PAPER(ARASHIYAMA)
# 1220  NEWS-PAPER(ARASHIYAMA)
# 1221  NEWS-PAPER(ARASHIYAMA)
# 1222  NEWS-PAPER(ARASHIYAMA)
# 1223  NEWS-PAPER(ARASHIYAMA)
# 1224  NEWS-PAPER(ARASHIYAMA)
# 1225  NEWS-PAPER(ARASHIYAMA)
# 1226  NEWS-PAPER(ARASHIYAMA)
# 1227  NEWS-PAPER(ARASHIYAMA)
# 1228  NEWS-PAPER(ARASHIYAMA)
# 1229  NEWS-PAPER(ARASHIYAMA)
# 1230  NEWS-PAPER(ARASHIYAMA)
# 1231  NEWS-PAPER(ARASHIYAMA)
# 1232  NEWS-PAPER(ARASHIYAMA)
# 1233  NEWS-PAPER(ARASHIYAMA)
# 1234  NEWS-PAPER(ARASHIYAMA)
# 1235  NEWS-PAPER(ARASHIYAMA)
# 1236  NEWS-PAPER(ARASHIYAMA)
# 1237  NEWS-PAPER(ARASHIYAMA)
# 1238  NEWS-PAPER(ARASHIYAMA)
# 1239  NEWS-PAPER(ARASHIYAMA)
#
# [1215 rows x 6 columns]

# %% [markdown]
# ## 5. What source is the most common as a reference?

# %%
df.dtypes
# Out:
# AD                       int64
# DOY                    float64
# Full_flowering_date    float64
# Source_code            float64
# Data_type_code         float64
# Reference_Name          object
# dtype: object

# %%
df.Source_code.value_counts()
# Out:
# 3.0    342
# 4.0    250
# 1.0    105
# 5.0     59
# 7.0     40
# 2.0     17
# 6.0      9
# 8.0      5
# Name: Source_code, dtype: int64

# %% [markdown]
# ## 6. Filter the list to only include columns where the `Full-flowering date (DOY)` is not missing
#
# If you'd like to do it in two steps (which might be easier to think through), first figure out how to test whether a column is empty/missing/null/NaN, get the list of `True`/`False` values, and then later feed it to your `df`.

# %%
df.DOY.value_counts(dropna=False)
# Out:
# NaN      388
# 104.0     56
# 105.0     53
# 106.0     49
# 102.0     48
# 103.0     47
# 108.0     46
# 107.0     41
# 109.0     41
# 101.0     38
# 98.0      37
# 112.0     36
# 99.0      36
# 110.0     35
# 100.0     32
# 111.0     32
# 97.0      31
# 113.0     22
# 96.0      21
# 95.0      19
# 93.0      15
# 114.0     14
# 115.0     13
# 94.0      11
# 116.0      9
# 120.0      8
# 117.0      7
# 92.0       6
# 119.0      4
# 91.0       4
# 87.0       4
# 118.0      3
# 122.0      2
# 89.0       2
# 88.0       2
# 86.0       1
# 124.0      1
# 90.0       1
# Name: DOY, dtype: int64

# %% [markdown]
# ## 7. Make a histogram of the full-flowering date
#
# Is it not showing up? Remember the "magic" command that makes graphs show up in matplotlib notebooks!

# %%
df.DOY.value_counts().hist()

# %% [markdown]
# ## 8. Make another histogram of the full-flowering date, but with 39 bins instead of 10

# %%
df.DOY.value_counts().hist(bins=39)

# %% [markdown]
# ## 9. What's the average number of days it takes for the flowers to blossom? And how many records do we have?
#
# Answer these both with one line of code.

# %%
df.DOY.describe()
# Out:
# count    827.000000
# mean     104.540508
# std        6.407036
# min       86.000000
# 25%      100.000000
# 50%      105.000000
# 75%      109.000000
# max      124.000000
# Name: DOY, dtype: float64

# %% [markdown]
# ## 10. What's the average days into the year cherry flowers normally blossomed before 1900?

# %%
(df.AD>=1900).mean()
# Out:
# 0.09547325102880659

# %% [markdown]
# ## 11. How about after 1900?

# %%
(df.AD<=1900).mean()
# Out:
# 0.9053497942386831

# %% [markdown]
# ## 12. How many times was our data from a title in Japanese poetry?
#
# You'll need to read the documentation inside of the Excel file.

# %%
#Data_type_code
#4=poetry

df.Data_type_code.value_counts()
# Out:
# 2.0    454
# 1.0    166
# 0.0    124
# 4.0     39
# 3.0     30
# 8.0     11
# 9.0      3
# Name: Data_type_code, dtype: int64

# %% [markdown]
# ## 13. Show only the years where our data was from a title in Japanese poetry

# %%
df[df.Data_type_code == 4]
# Out:
#         AD    DOY  Full_flowering_date  Source_code  Data_type_code  \
# 115    891  109.0                419.0          5.0             4.0
# 119    895  104.0                414.0          5.0             4.0
# 120    896  104.0                413.0          5.0             4.0
# 147    923  104.0                414.0          5.0             4.0
# 179    955   89.0                330.0          5.0             4.0
# 193    969   98.0                408.0          5.0             4.0
# 231   1007  106.0                416.0          5.0             4.0
# 257   1033  102.0                412.0          5.0             4.0
# 260   1036  104.0                413.0          5.0             4.0
# 284   1060  108.0                417.0          5.0             4.0
# 285   1061   92.0                402.0          6.0             4.0
# 308   1084  120.0                429.0          5.0             4.0
# 319   1095  100.0                410.0          5.0             4.0
# 406   1182  104.0                414.0          6.0             4.0
# 414   1190  112.0                422.0          5.0             4.0
# 425   1201   96.0                406.0          5.0             4.0
# 440   1216  101.0                410.0          5.0             4.0
# 443   1219  101.0                411.0          5.0             4.0
# 445   1221   99.0                409.0          5.0             4.0
# 447   1223  116.0                426.0          5.0             4.0
# 460   1236   87.0                327.0          7.0             4.0
# 489   1265   98.0                408.0          6.0             4.0
# 492   1268  103.0                412.0          6.0             4.0
# 493   1269  100.0                410.0          3.0             4.0
# 495   1271  100.0                410.0          5.0             4.0
# 513   1289  107.0                417.0          3.0             4.0
# 525   1301   95.0                405.0          4.0             4.0
# 548   1324   98.0                407.0          5.0             4.0
# 554   1330  108.0                418.0          7.0             4.0
# 671   1447  111.0                421.0          3.0             4.0
# 677   1453  107.0                417.0          3.0             4.0
# 678   1454  105.0                415.0          3.0             4.0
# 698   1474   98.0                408.0          3.0             4.0
# 758   1534  108.0                418.0          3.0             4.0
# 816   1592   98.0                407.0          4.0             4.0
# 864   1640  103.0                412.0          3.0             4.0
# 885   1661   93.0                403.0          7.0             4.0
# 1070  1846   98.0                408.0          4.0             4.0
# 1087  1863  118.0                428.0          4.0             4.0
#
#                   Reference_Name
# 115                 NIHONKIRYAKU
# 119                 NIHONKIRYAKU
# 120      NIPPON-SANDAI-JITSUROKU
# 147           ZOKU-KOKIN-WAKASHU
# 179                      SHUISHO
# 193                 NIHONKIRYAKU
# 231               MIDO-KAMPAKUKI
# 257                 NIHONKIRYAKU
# 260                 NIHONKIRYAKU
# 284          SHIN-SENZAI-WAKASHU
# 285                 MOROZANE-SHU
# 308           ZOKU-GOSEN-WAKASHU
# 319                      CHUYUKI
# 406   TSUKIMOUDE-WAKASHU(PART-3)
# 414                 SHUGYOKU-SHU
# 425            INOKUMA-KAMPAKUKI
# 440             JUNTOKUIN-GYOSHU
# 443             JUNTOKUIN-GYOSHU
# 445                    SHUI-GUSO
# 447               MITSUTSUNE-SHU
# 460               SHIIBA-WAKASHU
# 489                   TAMEIE-SHU
# 492                   TAMEIE-SHU
# 493                ZOKU-SHIGUSHO
# 495          DAINAGON-TAMEIE-SHU
# 513          NAKANOTSUKASA-NIKKI
# 525                 SANEMI-KYOKI
# 548         HANAZONOTENNO-SHINKI
# 554                RINEI-WAKASHU
# 671                     SOKONSHU
# 677                     SOKONSHU
# 678                     SOKONSHU
# 698               ENROKUCHOKASHU
# 758       GONARAIN-GYOSEI-BASSHO
# 816              TOKITSUNE-KYOKI
# 864                   KYOHAKUSHU
# 885          BURUI-GENYO-WAKASHU
# 1070                  TEIEN-EISO
# 1087                  YATAKA-SHU

# %% [markdown]
# ## 14. Graph the full-flowering date (DOY) over time

# %%
df.DOY.plot(x="DOY", y="AD", figsize=(10,7))

# %% [markdown]
# ## 15. Smooth out the graph
#
# It's so jagged! You can use `df.rolling` to calculate a rolling average.
#
# The following code calculates a **10-year mean**, using the `AD` column as the anchor. If there aren't 20 samples to work with in a row, it'll accept down to 5. Neat, right?
#
# (We're only looking at the final 5)

# %%
df.rolling(10, on='AD', min_periods=5)['DOY'].mean().tail()
# Out:
# 1235    95.9
# 1236    96.9
# 1237    96.4
# 1238    96.6
# 1239    96.0
# Name: DOY, dtype: float64

# %%
df.rolling(10, on='AD', min_periods=5)['DOY'].mean().tail().plot(ylim=(80, 120))

# %% [markdown]
# Use the code above to create a new column called `rolling_date` in our dataset. It should be the 20-year rolling average of the flowering date. Then plot it, with the year on the x axis and the day of the year on the y axis.
#
# Try adding `ylim=(80, 120)` to your `.plot` command to make things look a little less dire.

# %% [markdown]
# ### 16. Add a month column
#
# Right now the "Full-flowering date" column is pretty rough. It uses numbers like '402' to mean "April 2nd" and "416" to mean "April 16th." Let's make a column to explain what month it happened in.
#
# * Every row that happened in April should have 'April' in the `month` column.
# * Every row that happened in March should have 'March' as the `month` column.
# * Every row that happened in May should have 'May' as the `month` column.
#
# **I've given you March as an example**, you just need to add in two more lines to do April and May.

# %%
df.loc[df['Full_flowering_date'] < 400, 'month'] = 'March'

# %%
df.loc[df['Full_flowering_date'] < 500, 'month'] = 'April'

# %%
df.loc[df['Full_flowering_date'] < 600, 'month'] = 'May'

# %% [markdown]
# ### 17. Using your new column, how many blossomings happened in each month?

# %%
df.month.value_counts()
# Out:
# May    827
# Name: month, dtype: int64

# %% [markdown]
# ### 18. Graph how many blossomings happened in each month.

# %%
df.month.value_counts().hist()

# %% [markdown]
# ## 19. Adding a day-of-month column
#
# Now we're going to add a new column called "day of month." It's actually a little tougher than it should be since the `Full-flowering date` column is a *float* instead of an integer.

# %%
df.Full_flowering_date.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-8a26e83e72af> in <module>
# ----> 1 df.Full_flowering_date.astype(int)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/internals/managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     532     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     533         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 534                             **kwargs)
#     535
#     536     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/internals/blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     631
#     632                     # _astype_nansafe works fine with 1-d only
# --> 633                     values = astype_nansafe(values.ravel(), dtype, copy=True)
#     634
#     635                 # TODO(extension)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     674
#     675         if not np.isfinite(arr).all():
# --> 676             raise ValueError('Cannot convert non-finite values (NA or inf) to '
#     677                              'integer')
#     678
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %% [markdown]
# And if you try to convert it to an int, **pandas yells at you!**

# %% [markdown]
# That's because, as you can read, you can't have an `NaN` be an integer. But, for some reason, it *can* be a float. Ugh! So what we'll do is **drop all of the na values, then convert them to integers to get rid of the decimals.**
#
# I'll show you the first 5 here.

# %%
df['Full_flowering_date'].dropna().astype(int).head()
# Out:
# 36    401
# 39    415
# 55    406
# 75    418
# 77    414
# Name: Full_flowering_date, dtype: int64

# %% [markdown]
# On the next line, I take the first character of the row and add a bunch of exclamation points on it. I want you to edit this code to **return the last TWO digits of the number**. This only shows you the first 5, by the way.
#
# You might want to look up 'list slicing.'

# %%
df['Full_flowering_date'].dropna().astype(int).astype(str).apply(lambda value: value[0] + "!!!").head()
# Out:
# 36    4!!!
# 39    4!!!
# 55    4!!!
# 75    4!!!
# 77    4!!!
# Name: Full_flowering_date, dtype: object

# %% [markdown]
# Now that you've successfully extracted the last two letters, save them into a new column called `'day-of-month'`

# %%
df['day-of-month'] = df['Full_flowering_date'].dropna().astype(int).astype(str).apply(lambda value: value[0] + "!!!")

# %%
df.head()
# Out:
#      AD  DOY  Full_flowering_date  Source_code  Data_type_code Reference_Name  \
# 25  801  NaN                  NaN          NaN             NaN            NaN
# 26  802  NaN                  NaN          NaN             NaN            NaN
# 27  803  NaN                  NaN          NaN             NaN            NaN
# 28  804  NaN                  NaN          NaN             NaN            NaN
# 29  805  NaN                  NaN          NaN             NaN            NaN
#
#    month day-of-month
# 25   NaN          NaN
# 26   NaN          NaN
# 27   NaN          NaN
# 28   NaN          NaN
# 29   NaN          NaN

# %% [markdown]
# ### 20. Adding a date column
#
# Now take the `'month'` and `'day-of-month'` columns and combine them in order to create a new column called `'date'`

# %%
df["date"] = df["month"] + df["day-of-month"]

# %%
df
# Out:
#         AD    DOY  Full_flowering_date  Source_code  Data_type_code  \
# 25     801    NaN                  NaN          NaN             NaN
# 26     802    NaN                  NaN          NaN             NaN
# 27     803    NaN                  NaN          NaN             NaN
# 28     804    NaN                  NaN          NaN             NaN
# 29     805    NaN                  NaN          NaN             NaN
# 30     806    NaN                  NaN          NaN             NaN
# 31     807    NaN                  NaN          NaN             NaN
# 32     808    NaN                  NaN          NaN             NaN
# 33     809    NaN                  NaN          NaN             NaN
# 34     810    NaN                  NaN          NaN             NaN
# 35     811    NaN                  NaN          NaN             NaN
# 36     812   92.0                401.0          1.0             2.0
# 37     813    NaN                  NaN          NaN             NaN
# 38     814    NaN                  NaN          NaN             NaN
# 39     815  105.0                415.0          1.0             2.0
# 40     816    NaN                  NaN          NaN             NaN
# 41     817    NaN                  NaN          NaN             NaN
# 42     818    NaN                  NaN          NaN             NaN
# 43     819    NaN                  NaN          NaN             NaN
# 44     820    NaN                  NaN          NaN             NaN
# 45     821    NaN                  NaN          NaN             NaN
# 46     822    NaN                  NaN          NaN             NaN
# 47     823    NaN                  NaN          NaN             NaN
# 48     824    NaN                  NaN          NaN             NaN
# 49     825    NaN                  NaN          NaN             NaN
# 50     826    NaN                  NaN          NaN             NaN
# 51     827    NaN                  NaN          NaN             NaN
# 52     828    NaN                  NaN          NaN             NaN
# 53     829    NaN                  NaN          NaN             NaN
# 54     830    NaN                  NaN          NaN             NaN
# ...    ...    ...                  ...          ...             ...
# 1210  1986  102.0                412.0          3.0             0.0
# 1211  1987   95.0                405.0          3.0             0.0
# 1212  1988  106.0                415.0          3.0             0.0
# 1213  1989   93.0                403.0          3.0             0.0
# 1214  1990   88.0                329.0          3.0             0.0
# 1215  1991   97.0                407.0          4.0             0.0
# 1216  1992   94.0                403.0          4.0             0.0
# 1217  1993   97.0                407.0          4.0             0.0
# 1218  1994   99.0                409.0          4.0             0.0
# 1219  1995   99.0                409.0          4.0             0.0
# 1220  1996  103.0                412.0          4.0             0.0
# 1221  1997   97.0                407.0          4.0             0.0
# 1222  1998   91.0                401.0          4.0             0.0
# 1223  1999   94.0                404.0          4.0             0.0
# 1224  2000  100.0                409.0          4.0             0.0
# 1225  2001   96.0                406.0          4.0             0.0
# 1226  2002   91.0                401.0          4.0             0.0
# 1227  2003   98.0                408.0          4.0             0.0
# 1228  2004   92.0                401.0          4.0             0.0
# 1229  2005   99.0                409.0          4.0             0.0
# 1230  2006   98.0                408.0          5.0             0.0
# 1231  2007   97.0                407.0          5.0             0.0
# 1232  2008   95.0                404.0          6.0             0.0
# 1233  2009   95.0                405.0          6.0             0.0
# 1234  2010   95.0                405.0          7.0             0.0
# 1235  2011   99.0                409.0          8.0             0.0
# 1236  2012  101.0                410.0          8.0             0.0
# 1237  2013   93.0                403.0          8.0             0.0
# 1238  2014   94.0                404.0          8.0             0.0
# 1239  2015   93.0                403.0          8.0             0.0
#
#               Reference_Name month day-of-month     date
# 25                       NaN   NaN          NaN      NaN
# 26                       NaN   NaN          NaN      NaN
# 27                       NaN   NaN          NaN      NaN
# 28                       NaN   NaN          NaN      NaN
# 29                       NaN   NaN          NaN      NaN
# 30                       NaN   NaN          NaN      NaN
# 31                       NaN   NaN          NaN      NaN
# 32                       NaN   NaN          NaN      NaN
# 33                       NaN   NaN          NaN      NaN
# 34                       NaN   NaN          NaN      NaN
# 35                       NaN   NaN          NaN      NaN
# 36                NIHON-KOKI   May         4!!!  May4!!!
# 37                       NaN   NaN          NaN      NaN
# 38                       NaN   NaN          NaN      NaN
# 39                NIHON-KOKI   May         4!!!  May4!!!
# 40                       NaN   NaN          NaN      NaN
# 41                       NaN   NaN          NaN      NaN
# 42                       NaN   NaN          NaN      NaN
# 43                       NaN   NaN          NaN      NaN
# 44                       NaN   NaN          NaN      NaN
# 45                       NaN   NaN          NaN      NaN
# 46                       NaN   NaN          NaN      NaN
# 47                       NaN   NaN          NaN      NaN
# 48                       NaN   NaN          NaN      NaN
# 49                       NaN   NaN          NaN      NaN
# 50                       NaN   NaN          NaN      NaN
# 51                       NaN   NaN          NaN      NaN
# 52                       NaN   NaN          NaN      NaN
# 53                       NaN   NaN          NaN      NaN
# 54                       NaN   NaN          NaN      NaN
# ...                      ...   ...          ...      ...
# 1210  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1211  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1212  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1213  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1214  NEWS-PAPER(ARASHIYAMA)   May         3!!!  May3!!!
# 1215  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1216  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1217  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1218  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1219  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1220  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1221  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1222  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1223  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1224  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1225  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1226  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1227  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1228  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1229  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1230  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1231  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1232  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1233  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1234  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1235  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1236  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1237  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1238  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
# 1239  NEWS-PAPER(ARASHIYAMA)   May         4!!!  May4!!!
#
# [1215 rows x 9 columns]

# %% [markdown]
# # YOU ARE DONE.
#
# And **incredible.**

# %%
# !!!!!!!!!!!
